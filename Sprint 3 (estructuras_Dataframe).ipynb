# %% [markdown]
# # Estructuras Dataframe

# %%
import pandas as pd

# %%
vuelos=pd.read_csv('DelayedFlights.csv')
vuelos
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0                 0  2008      1           3          4   2003.0        1955
# 1                 1  2008      1           3          4    754.0         735
# 2                 2  2008      1           3          4    628.0         620
# 3                 4  2008      1           3          4   1829.0        1755
# 4                 5  2008      1           3          4   1940.0        1915
# ...             ...   ...    ...         ...        ...      ...         ...
# 1936753     7009710  2008     12          13          6   1250.0        1220
# 1936754     7009717  2008     12          13          6    657.0         600
# 1936755     7009718  2008     12          13          6   1007.0         847
# 1936756     7009726  2008     12          13          6   1251.0        1240
# 1936757     7009727  2008     12          13          6   1110.0        1103
#
# ...

# %%
#Reducción a 200000 registros (filas) para trabajar en todos los ejercicios

vuelos=vuelos.sample(200000)

# %% [markdown]
# # Ejercicio 1.
# ## Visualización de todas las variables existentes en el DataFrame para la elección de las que tengan información relevante para su análisis estadístico, justificándolo.

# %%
# Comprobación de las variables (o columnas) existentes.

vuelos.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'Year',
#  'Month',
#  'DayofMonth',
#  'DayOfWeek',
#  'DepTime',
#  'CRSDepTime',
#  'ArrTime',
#  'CRSArrTime',
#  'UniqueCarrier',
#  'FlightNum',
#  'TailNum',
#  'ActualElapsedTime',
#  'CRSElapsedTime',
#  'AirTime',
#  'ArrDelay',
#  'DepDelay',
#  'Origin',
#  'Dest',
#  'Distance',
#  'TaxiIn',
#  'TaxiOut',
#  'Cancelled',
#  'CancellationCode',
#  'Diverted',
#  'CarrierDelay',
#  'WeatherDelay',
#  'NASDelay',
#  'SecurityDelay',
#  'LateAircraftDelay']

# %% [markdown]
# ### Información sobre el significado de cada variable
#
# "Year":
# año del vuelo (todos del 2008).
#
# "Month":
# mes del vuelo.
#
# "DayOfMonth":
# día del mes (1 a 31).
#
# "DayOfWeek":
# día de la semana.
#
# "DepTime":
# hora de salida real.
#
# "CRSDepTime":
# hora de salida programada.
#
# "ArrTime":
# hora de llegada real.
#
# "CRSArrTime":
# hora de llegada programada.
#
# "UniqueCarrier":
# ID de operador.
#
# "FlightNum":
# número de vuelo.
#
# "TailNum":
# número de cola del avión.
#
# "ActualElapsedTime":
# tiempo real transcurrido del vuelo, en minutos.
#
# "CRSElapsedTime":
# tiempo transcurrido programado del vuelo, en minutos.
#
# "AirTime":
# tiempo en el aire para el vuelo, en minutos.
#
# "ArrDelay":
# retardo de llegada, en minutos.
#
# "DepDelay":
# retraso de salida, en minutos.
#
# "Origin":
# aeropuerto de origen.
#
# "Dest":
# aeropuerto de destino.
#
# "Distance":
# distancia de vuelo, en millas.
#
# "TaxiIn":
# tiempo de rodaje desde las ruedas hasta la llegada a la puerta, en minutos.
#
# "TaxiOut":
# tiempo de rodaje desde la salida de la puerta hasta las ruedas, en minutos.
#
# "Cancelled":
# estado de cancelación, donde Sí=1 y No=0.
#
# "CancellationCode":
# código de cancelación, en caso de existir.
#
# "Diverted":
# estado de desvío, donde Sí=1 y No=0.
#
# "CarrierDelay":
# retardo, en minutos, atribuible al transportista.
#
# "WeatherDelay":
# retraso, en minutos, atribuible a factores meteorológicos.
#
# "NASDelay":
# retraso, en minutos, atribuible al Sistema Nacional de Aviación.
#
# "SecurityDelay":
# retardo, en minutos, atribuible a factores de seguridad.
#
# "LateAircraftDelay":
# retraso, en minutos, atribuible a aeronaves que llegan tarde.

# %% [markdown]
# ### Eliminación de columnas

# %% [markdown]
# Como el objetivo del nuevo DataFrame es su análisis estadístico sobre los tiempos de los vuelos, he eliminado las variables (o columnas) que carecen de tal fin, tales como:
#
# 'Unnamed: 0', aparentemente tiene la forma de un indice para el dataset, aunque no tiene un orden consecutivo. Aún así, pandas ya generará un indice ordenado de números para cada registro;
#
# 'Year', ya que todos los registros corresponden al año 2008;
#
# 'FlightNUm' y 'TailNum', ambas solo contienen información de interés al ámbito de control interno para las compañías aéreas;
#
# 'TaxiIn' y 'TaxiOut', ya están dentro del tiempo de vuelo;
#
# 'CancellationCode', lo que interesa es disponer de si existe cancelación o no del vuelo (algo con lo que el dataframe ya cuenta);
#
# 'CarrierDelay', 'WeatherDelay', 'NASDelay', ' 'SecurityDelay' y 'LateAircraftDelay', aquí no analizamos la responsabilidad por el retraso del vuelo, sino los tiempos que se han empleado (además, muchos de sus valores carecen de registro).

# %% [markdown]
# ### En consecuencia, el nuevo dataframe quedaría de la siguiente manera:

# %%
vuelos.drop(['Unnamed: 0', 'Year', 'FlightNum', 'TailNum', 'TaxiIn', 'TaxiOut', 'CancellationCode', 
             'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'], axis=1, inplace=True)
vuelos
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 505472       3           8          6   1520.0        1455   1619.0
# 1062578      6          14          6   2252.0        2005    311.0
# 1736297     12           6          6   1359.0        1350   1634.0
# 132041       1          21          1   2259.0        2140    600.0
# 1622652     10          11          6   1534.0        1525   1754.0
# ...        ...         ...        ...      ...         ...      ...
# 1607025     10          28          2   2232.0        2105    114.0
# 856168       5          28          3   1707.0        1655   2253.0
# 1652900     11          15          6   1441.0        1229   1600.0
# 1814438     12          21          7    944.0         842   1107.0
# 1744271     12          16          2   1956.0        1940   2104.0
#
#          CRSArrTime UniqueCarrier  ActualElapsedTime  CRSElapsedTime  AirTime  \
# ...

# %% [markdown]
# ## Ejercicio 2

# %%
# a) Resumen estadístico y análisis de datos relevantes (no habituales o evidentes)
vuelos[['CRSDepTime', 'ActualElapsedTime',
        'AirTime', 'DepDelay', 'ArrDelay', 'Distance']].describe().round(2)
# Out:
#        CRSDepTime  ActualElapsedTime    AirTime   DepDelay   ArrDelay  \
# count   200000.00          199181.00  199181.00  200000.00  199181.00
# mean      1467.86             133.39     108.36      43.40      42.40
# std        425.63              71.99      68.56      53.42      56.83
# min          1.00              16.00       0.00       6.00     -68.00
# 25%       1133.00              80.00      58.00      12.00       9.00
# 50%       1510.00             116.00      90.00      24.00      25.00
# 75%       1819.00             165.00     137.00      54.00      56.00
# max       2359.00             727.00     637.00    1490.00    1490.00
#
#         Distance
# count  200000.00
# mean      766.59
# std       574.07
# min        11.00
# 25%       338.00
# 50%       607.00
# 75%      1005.00
# max      4962.00

# %% [markdown]
# Como puede observarse, la mitad de los vuelos se efectúan pasado poco más el mediodía (unos minutos después de las 15:00), y solo tres horas más tarde (alrededor de las 18:00) ya se han realizado el 75%.
#
# Por otra parte, la media del transcurso real de los vuelos es de 133.39 minutos.
#
# También llama la atención el vuelo que emplea solo un minuto en el aire (* en la siguiente línea podrá verse tal/es registro/s), Como es lógico, se trata de algún fallo en el mismo, mas no de un 'outlier', ya que el la distancia de estos vuelos llega a las 932 millas.
#
# El mismo tiempo de retraso de las salidas se traslada al de las llegadas, así se puede ver en sus respectivas medias, las cuales son prácticamente idénticas.
#
# Los datos registrados en los retrasos de llegada son verdaderamente extremos, hay mucha dispersión. Así lo reflejan sus desviaciones típicas, las cuales están incluso por encima de sus respectivas medias. Destacando en los retrasos de llegada un valor en negativo, lo que supone un adelanto en la llegada con respecto a la hora programada de 68 minutos (**).
#
# Por último, cabe resaltar la distancia máxima de 4962 kms y la mínima de 30 kms, también con una desviación típida muy extensa, y con una media de 766.59 kms recorridos por cada vuelo.

# %%
# * visualización del resgistro con valor de 1 minuto en el tiempo de vuelo
vuelos[vuelos.AirTime==1]
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 1178266      7          11          5   1015.0        1002   1249.0
# 950529       6          17          2   1136.0        1130   1213.0
#
#          CRSArrTime UniqueCarrier  ActualElapsedTime  CRSElapsedTime  AirTime  \
# 1178266        1234            EV              154.0           152.0      1.0
# 950529         1211            OO               37.0            41.0      1.0
#
#          ArrDelay  DepDelay Origin Dest  Distance  Cancelled  Diverted
# 1178266      15.0      13.0    FLL  CVG       932          0         0
# 950529        2.0       6.0    LAX  OXR        49          0         0

# %%
# ** visualización del registro con máximo adelanto de la llegada
vuelos[vuelos.ArrDelay==-68]
# Out:
#         Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 352034      2          13          3    907.0         900   1202.0
#
#         CRSArrTime UniqueCarrier  ActualElapsedTime  CRSElapsedTime  ...  \
# 352034        1310            AQ              295.0           370.0  ...
#
#         ArrDelay  DepDelay  Origin Dest Distance  Cancelled  Diverted  \
# 352034     -68.0       7.0     SNA  KOA     2530          0         0
#
#         AvarageSpeed  Delay_WithinTime TaxiIn_and_TaxiOut
# 352034        534.51        WithinTime               11.0
#
# [1 rows x 21 columns]

# %% [markdown]
# ### b) Datos faltantes por columna

# %%
vuelos.isna().sum()
# Out:
# Month                  0
# DayofMonth             0
# DayOfWeek              0
# DepTime                0
# CRSDepTime             0
# ArrTime              707
# CRSArrTime             0
# UniqueCarrier          0
# ActualElapsedTime    819
# CRSElapsedTime        19
# AirTime              819
# ArrDelay             819
# DepDelay               0
# Origin                 0
# Dest                   0
# Distance               0
# Cancelled              0
# Diverted               0
# dtype: int64

# %%
print('Si sumamos todos los datos faltantes, hay un total de', vuelos.isna().sum().sum(), 'valores carentes de contenido.')
# Out:
# Si sumamos todos los datos faltantes, hay un total de 3183 valores carentes de contenido.

# %%
#Comprobación de los registros (o filas) con valores nulos

vuelos[vuelos.isna().any(axis=1)]
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 1747420     12          17          3   2054.0        1940      NaN
# 275915       2          26          2   1326.0        1311      NaN
# 1918040     12          19          5   1038.0         940      NaN
# 312727       2           4          1   1347.0        1305      NaN
# 1909951     12          26          5   1259.0        1245   2151.0
# ...        ...         ...        ...      ...         ...      ...
# 319456       2           4          1   1806.0        1720      NaN
# 1809146     12          22          1    934.0         922      NaN
# 1765191     12          26          5   1332.0        1240      NaN
# 116475       1           6          7   1427.0        1420      NaN
# 1752082     12          19          5   1501.0        1245    225.0
#
#          CRSArrTime UniqueCarrier  ActualElapsedTime  CRSElapsedTime  AirTime  \
# ...

# %%
vuelos.isna().any(axis=1).sum()
# Out:
# 819

# %% [markdown]
# Como la cantidad de las filas con datos nulos son prácticamente insignificantes en proporción a la cantidad de filas totales (no llega ni al 0.5%), y con la finalidad de mantener todos los registros, la cancelación de estos valores no inlfuirá en análisis de cualquier tipo que se realice sobre el dataset.

# %% [markdown]
# #### Eliminación de las filas con datos nulos

# %%
c=vuelos.apply(lambda x: x['Cancelled']==1, axis=1).sum()
d=vuelos.apply(lambda x: x['Diverted']==1, axis=1).sum()

print(f'Hay {c} vuelos canceldos')

print(f'Hay {d} vuelos desviados')

print('Puede observarse que los valores nulos pertenecen a los registros que constan como vuelos nulos y cancelados:', c+d,',\ncoincidentes con los datos nulos totales de la variables ActualElapsedTime, AirTime y ArrDelay')
# Out:
# Hay 67 vuelos canceldos
# Hay 752 vuelos desviados
# Puede observarse que los valores nulos pertenecen a los registros que constan como vuelos nulos y cancelados: 819 ,
# coincidentes con los datos nulos totales de la variables ActualElapsedTime, AirTime y ArrDelay

# %%
# Eliminación de los datos nulos después de la información señalada

vuelos = vuelos.drop(vuelos[vuelos['Cancelled']==1].index)
vuelos = vuelos.drop(vuelos[vuelos['Diverted']==1].index)
vuelos.isna().sum()
# Out:
# Month                0
# DayofMonth           0
# DayOfWeek            0
# DepTime              0
# CRSDepTime           0
# ArrTime              0
# CRSArrTime           0
# UniqueCarrier        0
# ActualElapsedTime    0
# CRSElapsedTime       0
# AirTime              0
# ArrDelay             0
# DepDelay             0
# Origin               0
# Dest                 0
# Distance             0
# Cancelled            0
# Diverted             0
# dtype: int64

# %% [markdown]
# ### c) Creación de nuevas columnas

# %% [markdown]
# #### Velocidad media por vuelo

# %%
vuelos['AvarageSpeed']= (vuelos['Distance'] / vuelos['AirTime']*60).round(2)
vuelos
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 505472       3           8          6   1520.0        1455   1619.0
# 1062578      6          14          6   2252.0        2005    311.0
# 1736297     12           6          6   1359.0        1350   1634.0
# 132041       1          21          1   2259.0        2140    600.0
# 1622652     10          11          6   1534.0        1525   1754.0
# ...        ...         ...        ...      ...         ...      ...
# 1607025     10          28          2   2232.0        2105    114.0
# 856168       5          28          3   1707.0        1655   2253.0
# 1652900     11          15          6   1441.0        1229   1600.0
# 1814438     12          21          7    944.0         842   1107.0
# 1744271     12          16          2   1956.0        1940   2104.0
#
#          CRSArrTime UniqueCarrier  ActualElapsedTime  CRSElapsedTime  AirTime  \
# ...

# %% [markdown]
# #### Vuelo con retraso o dentro de hora

# %%
import numpy as np

vuelos['Delay_WithinTime']=np.where(vuelos['ArrDelay']>0, 'Delay', 'WithinTime')
vuelos
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 505472       3           8          6   1520.0        1455   1619.0
# 1062578      6          14          6   2252.0        2005    311.0
# 1736297     12           6          6   1359.0        1350   1634.0
# 132041       1          21          1   2259.0        2140    600.0
# 1622652     10          11          6   1534.0        1525   1754.0
# ...        ...         ...        ...      ...         ...      ...
# 1607025     10          28          2   2232.0        2105    114.0
# 856168       5          28          3   1707.0        1655   2253.0
# 1652900     11          15          6   1441.0        1229   1600.0
# 1814438     12          21          7    944.0         842   1107.0
# 1744271     12          16          2   1956.0        1940   2104.0
#
#          CRSArrTime UniqueCarrier  ActualElapsedTime  CRSElapsedTime  AirTime  \
# ...

# %% [markdown]
# #### (Creación de nueva columna) Tiempo de carreteo o movimiento del avión sobre tierra

# %%
vuelos['TaxiIn_and_TaxiOut']=(vuelos['ActualElapsedTime'] - vuelos['AirTime']).round(2)
vuelos
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 505472       3           8          6   1520.0        1455   1619.0
# 1062578      6          14          6   2252.0        2005    311.0
# 1736297     12           6          6   1359.0        1350   1634.0
# 132041       1          21          1   2259.0        2140    600.0
# 1622652     10          11          6   1534.0        1525   1754.0
# ...        ...         ...        ...      ...         ...      ...
# 1607025     10          28          2   2232.0        2105    114.0
# 856168       5          28          3   1707.0        1655   2253.0
# 1652900     11          15          6   1441.0        1229   1600.0
# 1814438     12          21          7    944.0         842   1107.0
# 1744271     12          16          2   1956.0        1940   2104.0
#
#          CRSArrTime UniqueCarrier  ActualElapsedTime  CRSElapsedTime  ...  \
# 505472         1600            MQ               59.0            65.0  ...
# ...

# %% [markdown]
# ### d) Tabla de aerolíneas con más retrasos acumulados. Muestra de mayor a menor

# %%
#Creación de un dataframe solo con valores 'Delay' (retraso) de la columna ya creada anteriormente 'Delay_WithinTime'

solo_retrasos=vuelos.groupby('Delay_WithinTime').get_group('Delay')
solo_retrasos
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 505472       3           8          6   1520.0        1455   1619.0
# 1062578      6          14          6   2252.0        2005    311.0
# 132041       1          21          1   2259.0        2140    600.0
# 1536998     10          20          1    712.0         705    924.0
# 868298       5          19          1   1931.0        1805   2209.0
# ...        ...         ...        ...      ...         ...      ...
# 1607025     10          28          2   2232.0        2105    114.0
# 856168       5          28          3   1707.0        1655   2253.0
# 1652900     11          15          6   1441.0        1229   1600.0
# 1814438     12          21          7    944.0         842   1107.0
# 1744271     12          16          2   1956.0        1940   2104.0
#
#          CRSArrTime UniqueCarrier  ActualElapsedTime  CRSElapsedTime  ...  \
# 505472         1600            MQ               59.0            65.0  ...
# ...

# %%
# Creación de un dataframe solo con valores 'Delay' (retraso) de la columna ya creada anteriormente 'Delay_WithinTime'
solo_retrasos=vuelos.groupby('Delay_WithinTime').get_group('Delay')


# Contabilización vuelos con retrasos por aerolínea
retrasos_aerol=pd.DataFrame(solo_retrasos.groupby('UniqueCarrier')['Delay_WithinTime'].value_counts())


# Contabilización vuelos totales por aerolínea
total_vuelos_aerol=pd.DataFrame(vuelos.groupby('UniqueCarrier')['Delay_WithinTime'].count())

# Porcentaje de vuelos retrasados con respecto a los vuelos totales por aerolínea
porcent_retr=(retrasos_aerol/total_vuelos_aerol)*100

porcent_retr.columns=['Porcentaje']
porcent_retr.sort_values(by='Porcentaje', ascending=False)
# Out:
#                                 Porcentaje
# UniqueCarrier Delay_WithinTime
# HA            Delay              95.572917
# YV            Delay              94.727011
# OH            Delay              93.497592
# OO            Delay              92.560223
# MQ            Delay              92.525702
# NW            Delay              91.787026
# EV            Delay              91.576443
# XE            Delay              91.510227
# FL            Delay              91.475635
# F9            Delay              90.699301
# 9E            Delay              90.581351
# AA            Delay              90.453715
# DL            Delay              88.879585
# UA            Delay              88.503269
# B6            Delay              87.445737
# AS            Delay              87.229713
# WN            Delay              86.403071
# US            Delay              85.054750
# AQ            Delay              84.848485
# CO            Delay              83.711021

# %% [markdown]
# ### e)  Los vuelos más largos. Muestra de los 10 primeros para tener una buena visión de esta variable, pero sin llegar a ser excesiva.
# #### # Matizar que el ejercicio no pide una nueva tabla solo con los valores de la columna de 'Distancia' o alguna más, de lo contrario habría procedido como en el ejercicio anterior. Se entiende que presente los registros de los vuelos más largos.

# %%
vuelos.sort_values(by='Distance', ascending=False).head(10)
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 719889       4          20          7   2316.0        1955   1510.0
# 1415598      8          13          3   1344.0        1335   1814.0
# 1926347     12          20          6   1441.0        1335   2123.0
# 1068315      6           2          1   1342.0        1335   1807.0
# 1725876     11          22          6   1413.0        1335   1958.0
# 718540       4          30          3   1408.0        1335   1843.0
# 556358       3          18          2   2207.0        2145   1326.0
# 556366       3           5          3   1335.0        1320   1920.0
# 1421428      8          22          5   1344.0        1335   1815.0
# 176119       1          26          6   1407.0        1320   1947.0
#
#          CRSArrTime UniqueCarrier  ActualElapsedTime  CRSElapsedTime  ...  \
# 719889         1130            CO              594.0           575.0  ...
# ...

# %%
pd.DataFrame(vuelos.groupby('UniqueCarrier')['Delay_WithinTime'].count())
# Out:
#                Delay_WithinTime
# UniqueCarrier
# 9E                         5298
# AA                        19704
# AQ                           66
# AS                         3931
# B6                         5759
# CO                        10326
# DL                        11942
# EV                         8405
# F9                         2860
# FL                         7285
# HA                          768
# MQ                        14396
# NW                         8170
# OH                         5398
# OO                        13616
# UA                        14378
# US                        10137
# WN                        39075
# XE                        10707
# YV                         6960

# %% [markdown]
# ### Los 10 vuelos con más retrasos.
# #### Procedimiento idem ejercicio anterior.

# %%
vuelos.sort_values(by='ArrDelay', ascending=False).head(10)
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 521096       3          21          5    705.0         615    811.0
# 1222506      7          30          3   1241.0        1445   2110.0
# 1400101      8          29          5    630.0         850    956.0
# 457238       3          29          6   1013.0        1305   1322.0
# 325724       2           3          7    939.0        1400   1358.0
# 1906664     12          17          3   1103.0        1430   1555.0
# 1599350     10          30          4    711.0        1205   1244.0
# 315641       2          29          5    713.0        1210    917.0
# 1698976     11          30          7   1115.0        1655   1318.0
# 1879242     12          21          7     27.0         615    222.0
#
#          CRSArrTime UniqueCarrier  ActualElapsedTime  CRSElapsedTime  ...  \
# 521096          721            NW               66.0            66.0  ...
# ...

# %% [markdown]
# ### Rutas más largas (seleccionadas las 10 primeras)

# %%
rutas_mas_larg = vuelos.drop_duplicates(subset = "Distance").sort_values(by = 'Distance', ascending = False).head(10)
rutas_mas_larg[['Origin', 'Dest', 'Distance']]
# Out:
#         Origin Dest  Distance
# 1415598    EWR  HNL      4962
# 1682456    ATL  HNL      4502
# 1809932    ORD  HNL      4243
# 1147070    KOA  ORD      4213
# 447765     ORD  OGG      4184
# 1706278    MSP  HNL      3972
# 1414945    HNL  IAH      3904
# 691514     DFW  HNL      3784
# 1385569    OGG  DFW      3711
# 1174269    ATL  ANC      3417

# %% [markdown]
# ### f) Nuevos datos que considere relevantes

# %% [markdown]
# #### Cantidad de vuelos por mes

# %%
vuelos_mes = vuelos['Month'].value_counts().reset_index()
vuelos_mes.columns=['Número del mes', 'Cantidad de vuelos']
vuelos_mes.sort_values('Cantidad de vuelos', ascending=False)
# Out:
#     Número del mes  Cantidad de vuelos
# 0                3               20907
# 1                6               20695
# 2               12               20585
# 3                2               19378
# 4                7               18911
# 5                1               18764
# 6                8               16796
# 7                4               16087
# 8                5               15689
# 9               11               10914
# 10              10               10667
# 11               9                9788

# %% [markdown]
# Los meses de Diciembre, Junio y Marzo son en los que más vuelos se realizan, mientras que en el mes de Septiembre es el que menos.

# %% [markdown]
# #### Cantidad vuelos por día del mes

# %%
vuelos_Dia_Mes=vuelos['DayofMonth'].value_counts().reset_index()
vuelos_Dia_Mes.columns=['Día del Mes', 'Cantidad de vuelos']
vuelos_Dia_Mes.sort_values('Cantidad de vuelos', ascending=False)
# Out:
#     Día del Mes  Cantidad de vuelos
# 0            22                7524
# 1            21                7244
# 2             1                6913
# 3             7                6891
# 4            15                6722
# 5            14                6689
# 6            27                6663
# 7            20                6646
# 8            18                6640
# 9            19                6636
# 10           11                6592
# 11           24                6577
# 12            2                6568
# 13            9                6560
# 14           17                6551
# 15           23                6532
# 16           10                6478
# 17            8                6451
# 18           26                6444
# 19           12                6341
# 20            4                6324
# 21            6                6324
# 22           13                6260
# 23           16                6254
# 24           28                6194
# ...

# %% [markdown]
# Llama la atención como precisamente los últimos días de cada mes (31, 30 y 29) es cuando se realizan menos vuelos, en cambio el día 1 está entre los tres primeros.

# %% [markdown]
# #### Cantidad vuelos por día de la semana

# %%
vuelos_Dia_Sem=vuelos['DayOfWeek'].value_counts().reset_index()
vuelos_Dia_Sem.columns=['Día de la semana', 'Cantidad de vuelos']
vuelos_Dia_Sem.sort_values('Cantidad de vuelos', ascending=False)
# Out:
#    Día de la semana  Cantidad de vuelos
# 0                 5               33434
# 1                 1               29865
# 2                 4               29683
# 3                 7               29498
# 4                 3               26913
# 5                 2               26908
# 6                 6               22880

# %% [markdown]
# En cuanto a los vuelos que se efectúan por día de la semana, el primer y último día laborables de la semana son los días que más vuelos se ejecutan. Por su parte, el sábado es el que menos.

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# #### Exportar el nuevo dataframe con las nuevas columnas añadidas a Excel

# %%
vuelos_colum_relev.to_excel('Vuelos_análisis.xlsx')
